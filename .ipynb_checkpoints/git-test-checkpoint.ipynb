# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
# グラフを描画
x = np.arange(0, 20, 0.1)
y = np.cos(x)
plt.plot(x,y)
plt.show()

# %%
print('Change file!')
# Out:
# Change file!

# %%
print('change !!!!')
# Out:
# change !!!!

# %%
print('master !!!!')
# Out:
# master !!!!
